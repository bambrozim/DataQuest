# %% [markdown]
# - Import the pandas package.
# - Use the pandas.read_csv() function to read the thanksgiving.csv file in.
#     - Make sure to specify the keyword argument encoding="Latin-1", as the CSV file isn't encoded normally.
#     - Assign the result to the variable data.
# - Display the first few rows of data to see what the columns and rows look like.
# - In a separate notebook cell, display all of the column names to get a sense of what the data consists of.
#     - You can use the pandas.DataFrame.columns property to display the column names.

# %%
import pandas as pd

data = pd.read_csv('thanksgiving.csv', encoding='Latin-1')

data.head()
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
data.columns
# Out:
# Index(['RespondentID', 'Do you celebrate Thanksgiving?',
#        'What is typically the main dish at your Thanksgiving dinner?',
#        'What is typically the main dish at your Thanksgiving dinner? - Other (please specify)',
#        'How is the main dish typically cooked?',
#        'How is the main dish typically cooked? - Other (please specify)',
#        'What kind of stuffing/dressing do you typically have?',
#        'What kind of stuffing/dressing do you typically have? - Other (please specify)',
#        'What type of cranberry saucedo you typically have?',
#        'What type of cranberry saucedo you typically have? - Other (please specify)',
#        'Do you typically have gravy?',
#        'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Brussel sprouts',
#        'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Carrots',
# ...

# %% [markdown]
# - Use the pandas.Series.value_counts() method to display counts of how many times each category occurs in the Do you celebrate Thanksgiving? column.
# - Filter out any rows in data where the response to Do you celebrate Thanksgiving? is not Yes. At the end, all of the values in the Do you celebrate Thanksgiving? column of data should be Yes.

# %%
data['Do you celebrate Thanksgiving?'].value_counts()
# Out:
# Yes    980
# No      78
# Name: Do you celebrate Thanksgiving?, dtype: int64

# %%
data[data['Do you celebrate Thanksgiving?']=='Yes']
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 0       4337954960                            Yes
# 1       4337951949                            Yes
# 2       4337935621                            Yes
# 3       4337933040                            Yes
# 4       4337931983                            Yes
# 5       4337929779                            Yes
# 6       4337924420                            Yes
# 7       4337916002                            Yes
# 8       4337914977                            Yes
# 9       4337899817                            Yes
# 11      4337893416                            Yes
# 12      4337888291                            Yes
# 13      4337878450                            Yes
# 14      4337878351                            Yes
# 15      4337857295                            Yes
# 16      4337856362                            Yes
# 17      4337854106                            Yes
# 18      4337844879                            Yes
# ...

# %% [markdown]
# - Use the pandas.Series.value_counts() method to display counts of how many times each category occurs in the What is typically the main dish at your Thanksgiving dinner? column.
# - Display the Do you typically have gravy? column for any rows from data where the What is typically the main dish at your Thanksgiving dinner? column equals Tofurkey.
#     - Create a filter that only selects rows from data where What is typically the main dish at your Thanksgiving dinner? equals Tofurkey.
#     - Select the Do you typically have gravy? column, and display it.

# %%
data['What is typically the main dish at your Thanksgiving dinner?'].value_counts()
# Out:
# Turkey                    859
# Other (please specify)     35
# Ham/Pork                   29
# Tofurkey                   20
# Chicken                    12
# Roast beef                 11
# I don't know                5
# Turducken                   3
# Name: What is typically the main dish at your Thanksgiving dinner?, dtype: int64

# %%
data[data['What is typically the main dish at your Thanksgiving dinner?']=='Tofurkey']['Do you typically have gravy?']
# Out:
# 4      Yes
# 33     Yes
# 69      No
# 72      No
# 77     Yes
# 145    Yes
# 175    Yes
# 218     No
# 243    Yes
# 275     No
# 393    Yes
# 399    Yes
# 571    Yes
# 594    Yes
# 628     No
# 774     No
# 820     No
# 837    Yes
# 860     No
# 953    Yes
# Name: Do you typically have gravy?, dtype: object

# %% [markdown]
# - Generate a Boolean Series indicating where the Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple column is null. Assign to the apple_isnull variable.
# - Generate a Boolean Series indicating where the Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin column is null. Assign to the pumpkin_isnull variable.
# - Generate a Boolean Series indicating where the Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan column is null. Assign to the pecan_isnull variable.
# - Join all three Series using the & operator, and assign the result to no_pies.
# - Display the unique values and how many times each occurs in the no_pies column.

# %%
apple_isnull = data['Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple'].isnull()

# %%
pumpkin_isnull = data['Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin'].isnull()

# %%
pecan_isnull = data['Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan'].isnull()

# %%
no_pies = apple_isnull & pumpkin_isnull & pecan_isnull

# %%
no_pies.value_counts()
# Out:
# False    876
# True     182
# dtype: int64

# %% [markdown]
# - Write a function to convert a single string to an appropriate integer value. This will allow us to convert the values in the Age column to integers.
#     - Use the isnull() function to check if the value is null. If it is, return None.
#     - Split the string on the space character (), and extract the first item of the resulting list.
#     - Replace the + character in the result with an empty string to remove it.
#     - Use int() to convert the result to an integer.
#     - Return the result.
# - Use the pandas.Series.apply() method to apply the function to each value in the Age column of data.
#     - Assign the result to the int_age column of data.
# - Call the pandas.Series.describe() method on the int_age column of data, and display the result.

# %%
def to_int(input_str):
    if pd.isnull(input_str):
        return None
    first_item = input_str.replace("+", " ").split(" ")[0]
    first_item = int(first_item)
    return first_item

data["int_age"] = data["Age"].apply(to_int)
data["int_age"].describe()
# Out:
# count    1025.000000
# mean       39.383415
# std        15.398493
# min        18.000000
# 25%        30.000000
# 50%        45.000000
# 75%        60.000000
# max        60.000000
# Name: int_age, dtype: float64

# %% [markdown]
# - Write a function to convert a single string to an appropriate integer income value.
#     - Use the isnull() function to check if the value is null. If it is, return None.
#     - Split the string on the space character (), and extract the first item of the resulting list.
#     - If the result equals Prefer, return None.
#     - Replace the \$ and , characters in the result with empty strings to remove them.
#     - Use int() to convert the result to an integer.
#     - Return the result.
# - Use the pandas.Series.apply() method to apply the function to each value in the How much total combined money did all members of your HOUSEHOLD earn last year? column of data.
#     - Assign the result to the int_income column of data.
# - Call the pandas.Series.describe() method on the int_income column of data, and display the result.

# %%
def to_int_income(input_str):
    if pd.isnull(input_str):
        return None
    income = input_str.replace("$", "").replace(",", "").split(" ")[0]
    if income == "Prefer":
        return None
    return int(income)

data["int_income"] = data["How much total combined money did all members of your HOUSEHOLD earn last year?"].apply(to_int_income)
data["int_income"].describe()
# Out:
# count       889.000000
# mean      74077.615298
# std       59360.742902
# min           0.000000
# 25%       25000.000000
# 50%       50000.000000
# 75%      100000.000000
# max      200000.000000
# Name: int_income, dtype: float64

# %% [markdown]
# - See how far people earning under 150000 will travel.
#     - Filter data, and only select rows where int_income is less than 150000.
#     - Use indexing to select the How far will you travel for Thanksgiving? column.
#     - Use the value_counts() method to count up how many times each value occurs in the column.
#     - Display the results.
# - See how far people earning over 150000 will travel.
#     - Filter data, and only select rows where int_income is greater than 150000.
#     - Use indexing to select the How far will you travel for Thanksgiving? column.
#     - Use the value_counts() method to count up how many times each value occurs in the column.
#     - Display the results

# %%
data[data["int_income"] < 150000]["How far will you travel for Thanksgiving?"].value_counts()
# Out:
# Thanksgiving is happening at my home--I won't travel at all                         281
# Thanksgiving is local--it will take place in the town I live in                     203
# Thanksgiving is out of town but not too far--it's a drive of a few hours or less    150
# Thanksgiving is out of town and far away--I have to drive several hours or fly       55
# Name: How far will you travel for Thanksgiving?, dtype: int64

# %%
data[data["int_income"] > 150000]["How far will you travel for Thanksgiving?"].value_counts()
# Out:
# Thanksgiving is happening at my home--I won't travel at all                         49
# Thanksgiving is local--it will take place in the town I live in                     25
# Thanksgiving is out of town but not too far--it's a drive of a few hours or less    16
# Thanksgiving is out of town and far away--I have to drive several hours or fly      12
# Name: How far will you travel for Thanksgiving?, dtype: int64

# %% [markdown]
# - Generate a pivot table showing the average age of respondents for each category of Have you ever tried to meet up with hometown friends on Thanksgiving night? and Have you ever attended a "Friendsgiving?".
#     - Call the pivot_table() method on data.
#     - Pass in "Have you ever tried to meet up with hometown friends on Thanksgiving night?" to the index keyword argument.
#     - Pass in 'Have you ever attended a "Friendsgiving?"' to the columns keyword argument.
#     - Pass in "int_age" to the values keyword argument.
#     - Display the results.
# - Generate a pivot table showing the average income of respondents for each category of Have you ever tried to meet up with hometown friends on Thanksgiving night? and Have you ever attended a "Friendsgiving?".

# %%
data.pivot_table(index='Have you ever tried to meet up with hometown friends on Thanksgiving night?', columns='Have you ever attended a "Friendsgiving?"', values='int_age')
# Out:
# Have you ever attended a "Friendsgiving?"                  No        Yes
# Have you ever tried to meet up with hometown fr...
# No                                                  42.283702  37.010526
# Yes                                                 41.475410  33.976744

# %%
data.pivot_table(index='Have you ever tried to meet up with hometown friends on Thanksgiving night?', columns='Have you ever attended a "Friendsgiving?"', values='int_income')
# Out:
#                                                     RespondentID  \
# Have you ever attended a "Friendsgiving?"                     No
# Have you ever tried to meet up with hometown fr...
# No                                                  4.336724e+09
# Yes                                                 4.336794e+09
#
#                                                                     int_age  \
# Have you ever attended a "Friendsgiving?"                    Yes         No
# Have you ever tried to meet up with hometown fr...
# No                                                  4.336679e+09  42.283702
# Yes                                                 4.336780e+09  41.475410
#
#                                                                  int_income  \
# Have you ever attended a "Friendsgiving?"                 Yes            No
# Have you ever tried to meet up with hometown fr...
# No                                                  37.010526  78914.549654
# ...

# %% [markdown]
# - Figure out the most common dessert people eat.

# %%
data[['Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Apple cobbler',
       'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Blondies',
       'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Brownies',
       'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Carrot cake',
       'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cheesecake',
       'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cookies',
       'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Fudge',
       'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Ice cream',
       'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Peach cobbler']].apply(pd.value_counts)
# Out:
#                Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Apple cobbler  \
# Apple cobbler                                              110.0
# Blondies                                                     NaN
# Brownies                                                     NaN
# Carrot cake                                                  NaN
# Cheesecake                                                   NaN
# Cookies                                                      NaN
# Fudge                                                        NaN
# Ice cream                                                    NaN
# Peach cobbler                                                NaN
#
#                Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Blondies  \
# Apple cobbler                                                NaN
# ...

# %% [markdown]
# Most common dessert is ice cream.

# %% [markdown]
# - Figure out the most common complete meal people eat.

# %%
data['What is typically the main dish at your Thanksgiving dinner?'].value_counts()
# Out:
# Turkey                    859
# Other (please specify)     35
# Ham/Pork                   29
# Tofurkey                   20
# Chicken                    12
# Roast beef                 11
# I don't know                5
# Turducken                   3
# Name: What is typically the main dish at your Thanksgiving dinner?, dtype: int64

# %%
data['How is the main dish typically cooked?'].value_counts()
# Out:
# Baked                     481
# Roasted                   378
# Other (please specify)     51
# Fried                      47
# I don't know               17
# Name: How is the main dish typically cooked?, dtype: int64

# %% [markdown]
# Main dish: Baked Turkey

# %%
data['What kind of stuffing/dressing do you typically have?'].value_counts()
# Out:
# Bread-based               836
# None                       60
# Rice-based                 42
# Other (please specify)     36
# Name: What kind of stuffing/dressing do you typically have?, dtype: int64

# %% [markdown]
# Bread-based stuffing/dressing.

# %%
data['What type of cranberry saucedo you typically have?'].value_counts()
# Out:
# Canned                    502
# Homemade                  301
# None                      146
# Other (please specify)     25
# Name: What type of cranberry saucedo you typically have?, dtype: int64

# %% [markdown]
# Canned cranberry saucedo.

# %%
data['Do you typically have gravy?'].value_counts()
# Out:
# Yes    892
# No      82
# Name: Do you typically have gravy?, dtype: int64

# %% [markdown]
# With gravy.

# %%
data[['Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Brussel sprouts',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Carrots',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cauliflower',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Corn',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cornbread',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Fruit salad',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Green beans/green bean casserole',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Macaroni and cheese',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Mashed potatoes',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Rolls/biscuits',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Squash',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Vegetable salad',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Yams/sweet potato casserole']].apply(pd.value_counts)
# Out:
#                                   Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Brussel sprouts  \
# Brussel sprouts                                                               155.0
# Carrots                                                                         NaN
# Cauliflower                                                                     NaN
# Corn                                                                            NaN
# Cornbread                                                                       NaN
# Fruit salad                                                                     NaN
# Green beans/green bean casserole                                                NaN
# Macaroni and cheese                                                             NaN
# Mashed potatoes                                                                 NaN
# ...

# %% [markdown]
# Most common side dishes: Mashed Potatoes, Rolls/biscuits and Green beans.

# %%
data[['Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple',
       'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Buttermilk',
       'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Cherry',
       'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Chocolate',
       'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Coconut cream',
       'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Key lime',
       'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Peach',
       'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan',
       'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin',
       'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Sweet Potato',
       'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - None']].apply(pd.value_counts)
# Out:
#                Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple  \
# Apple                                                      514.0
# Buttermilk                                                   NaN
# Cherry                                                       NaN
# Chocolate                                                    NaN
# Coconut cream                                                NaN
# Key lime                                                     NaN
# None                                                         NaN
# Peach                                                        NaN
# Pecan                                                        NaN
# Pumpkin                                                      NaN
# Sweet Potato                                                 NaN
#
#                Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Buttermilk  \
# ...

# %% [markdown]
# Pumpkin pie.

# %% [markdown]
# And ice cream for dessert.

# %% [markdown]
# - Identify how many people work on Thanksgiving.

# %%
data['Will you employer make you work on Black Friday?'].value_counts()
# Out:
# Yes              43
# No               20
# Doesn't apply     7
# Name: Will you employer make you work on Black Friday?, dtype: int64

# %% [markdown]
# - Find regional patterns in the dinner menus.

# %%
data['US Region'].value_counts()
# Out:
# South Atlantic        214
# Middle Atlantic       159
# East North Central    150
# Pacific               146
# West South Central     91
# West North Central     74
# East South Central     60
# New England            58
# Mountain               47
# Name: US Region, dtype: int64

# %%
def main_dish(region):
    main_dish = data[data['US Region']==region][['US Region', 'What is typically the main dish at your Thanksgiving dinner?',
       'How is the main dish typically cooked?',
       'What kind of stuffing/dressing do you typically have?',
       'What type of cranberry saucedo you typically have?',
       'Do you typically have gravy?']]
    return main_dish.apply(pd.value_counts).idxmax()

def side_dishes(region):
    side_dishes = data[data['US Region']==region][['Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Brussel sprouts',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Carrots',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cauliflower',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Corn',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cornbread',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Fruit salad',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Green beans/green bean casserole',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Macaroni and cheese',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Mashed potatoes',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Rolls/biscuits',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Squash',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Vegetable salad',
       'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Yams/sweet potato casserole']].apply(pd.value_counts)
    return side_dishes.max().sort_values(ascending=False)

def pie(region):
    pies = data[data['US Region']==region][['Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple',
       'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Buttermilk',
       'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Cherry',
       'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Chocolate',
       'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Coconut cream',
       'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Key lime',
       'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Peach',
       'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan',
       'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin',
       'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Sweet Potato',
       'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - None']].apply(pd.value_counts)
    return pies.max().sort_values(ascending=False)

def dessert(region):
    desserts = data[data['US Region']==region][['Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Apple cobbler',
       'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Blondies',
       'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Brownies',
       'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Carrot cake',
       'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cheesecake',
       'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cookies',
       'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Fudge',
       'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Ice cream',
       'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Peach cobbler',
       'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - None']].apply(pd.value_counts)
    return desserts.max().sort_values(ascending=False)

# %% [markdown]
# **South Atlantic**

# %%
main_dish('South Atlantic')
# Out:
# US Region                                                       South Atlantic
# What is typically the main dish at your Thanksgiving dinner?            Turkey
# How is the main dish typically cooked?                                   Baked
# What kind of stuffing/dressing do you typically have?              Bread-based
# What type of cranberry saucedo you typically have?                      Canned
# Do you typically have gravy?                                               Yes
# dtype: object

# %%
side_dishes('South Atlantic')
# Out:
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Rolls/biscuits                      158.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Mashed potatoes                     157.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Green beans/green bean casserole    150.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Yams/sweet potato casserole         144.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Corn                                 96.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Macaroni and cheese                  79.0
# ...

# %%
pie('South Atlantic')
# Out:
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin          135.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple            101.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan             78.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Sweet Potato      50.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Chocolate         32.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Cherry            20.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Key lime          17.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - None              12.0
# ...

# %%
dessert('South Atlantic')
# Out:
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Ice cream        56.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cheesecake       48.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - None             47.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cookies          40.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Brownies         32.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Peach cobbler    29.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Apple cobbler    24.0
# ...

# %% [markdown]
# South Atlantic dinner<br>
# - main dish: Baked Turkey
# - bread-based stuffing/dressing
# - canned cranberry saucedo
# - with gravy
# - side dishes: Rolls/biscuits, Mashed potatoes and Green beans
# - Pumpkin Pie
# - Ice cream for dessert

# %% [markdown]
# **Middle Atlantic**

# %%
main_dish('Middle Atlantic')
# Out:
# US Region                                                       Middle Atlantic
# What is typically the main dish at your Thanksgiving dinner?             Turkey
# How is the main dish typically cooked?                                  Roasted
# What kind of stuffing/dressing do you typically have?               Bread-based
# What type of cranberry saucedo you typically have?                       Canned
# Do you typically have gravy?                                                Yes
# dtype: object

# %%
side_dishes('Middle Atlantic')
# Out:
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Mashed potatoes                     130.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Rolls/biscuits                      106.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Yams/sweet potato casserole          99.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Green beans/green bean casserole     92.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Corn                                 77.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Carrots                              45.0
# ...

# %%
pie('Middle Atlantic')
# Out:
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin          115.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple            106.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan             31.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Sweet Potato      21.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Cherry            17.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Chocolate         16.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Coconut cream      9.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - None               6.0
# ...

# %%
dessert('Middle Atlantic')
# Out:
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Ice cream        51.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - None             40.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cookies          40.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cheesecake       34.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Apple cobbler    23.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Brownies         18.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Carrot cake      17.0
# ...

# %% [markdown]
# Middle Atlantic dinner
# - main dish: Roasted Turkey
# - bread-based stuffing/dressing
# - canned cranberry saucedo
# - with gravy
# - side dishes: Mashed potatoes, Rolls/biscuits and Yams/Sweet potato
# - Pumpkin Pie
# - Ice cream for dessert

# %% [markdown]
# **East North Central**

# %%
main_dish('East North Central')
# Out:
# US Region                                                       East North Central
# What is typically the main dish at your Thanksgiving dinner?                Turkey
# How is the main dish typically cooked?                                       Baked
# What kind of stuffing/dressing do you typically have?                  Bread-based
# What type of cranberry saucedo you typically have?                          Canned
# Do you typically have gravy?                                                   Yes
# dtype: object

# %%
side_dishes('East North Central')
# Out:
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Mashed potatoes                     127.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Rolls/biscuits                      123.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Green beans/green bean casserole    103.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Yams/sweet potato casserole          90.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Corn                                 76.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Carrots                              28.0
# ...

# %%
pie('East North Central')
# Out:
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin          113.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple             75.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan             47.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Cherry            22.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Sweet Potato      16.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Chocolate         11.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - None               7.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Peach              3.0
# ...

# %%
dessert('East North Central')
# Out:
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - None             49.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Ice cream        41.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cookies          27.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cheesecake       22.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Brownies         16.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Apple cobbler    13.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Peach cobbler     9.0
# ...

# %% [markdown]
# East North Central
# - main dish: Baked Turkey
# - bread-based stuffing/dressing
# - canned cranberry saucedo
# - with gravy
# - side dishes: Mashed potatoes, Rolls/biscuits and Green beans
# - Pumpkin Pie
# - nothing for dessert

# %% [markdown]
# **Pacific**

# %%
main_dish('Pacific')
# Out:
# US Region                                                           Pacific
# What is typically the main dish at your Thanksgiving dinner?         Turkey
# How is the main dish typically cooked?                                Baked
# What kind of stuffing/dressing do you typically have?           Bread-based
# What type of cranberry saucedo you typically have?                   Canned
# Do you typically have gravy?                                            Yes
# dtype: object

# %%
side_dishes('Pacific')
# Out:
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Mashed potatoes                     112.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Rolls/biscuits                       99.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Yams/sweet potato casserole          85.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Green beans/green bean casserole     84.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Corn                                 55.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Vegetable salad                      39.0
# ...

# %%
pie('Pacific')
# Out:
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin          105.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple             74.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan             37.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Cherry            20.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Sweet Potato      13.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Chocolate         13.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Peach              8.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Coconut cream      5.0
# ...

# %%
dessert('Pacific')
# Out:
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - None             43.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Ice cream        32.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cookies          25.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cheesecake       23.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Apple cobbler    18.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Brownies         15.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Peach cobbler    14.0
# ...

# %% [markdown]
# Pacific
# - main dish: Baked Turkey
# - bread-based stuffing/dressing
# - canned cranberry saucedo
# - with gravy
# - side dishes: Mashed potatoes, Rolls/biscuits and Yams/Sweet potato
# - Pumpkin Pie
# - nothing for dessert

# %% [markdown]
# **West South Central**

# %%
main_dish('West South Central')
# Out:
# US Region                                                       West South Central
# What is typically the main dish at your Thanksgiving dinner?                Turkey
# How is the main dish typically cooked?                                       Baked
# What kind of stuffing/dressing do you typically have?                  Bread-based
# What type of cranberry saucedo you typically have?                          Canned
# Do you typically have gravy?                                                   Yes
# dtype: object

# %%
side_dishes('West South Central')
# Out:
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Rolls/biscuits                      73.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Mashed potatoes                     70.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Green beans/green bean casserole    66.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Yams/sweet potato casserole         63.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Corn                                46.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cornbread                           34.0
# ...

# %%
pie('West South Central')
# Out:
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin          68.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan            53.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple            32.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Sweet Potato     19.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Chocolate        19.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Buttermilk       13.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Cherry            9.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Key lime          7.0
# ...

# %%
dessert('West South Central')
# Out:
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - None             27.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Ice cream        23.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Peach cobbler    21.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cheesecake       20.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cookies          16.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Brownies         12.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Apple cobbler    11.0
# ...

# %% [markdown]
# West South Central
# - main dish: Baked Turkey
# - bread-based stuffing/dressing
# - canned cranberry saucedo
# - with gravy
# - side dishes: Rolls/biscuits, Mashed potatoes and Green beans
# - Pumpkin Pie
# - nothing for dessert

# %% [markdown]
# **West North Central**

# %%
main_dish('West North Central')
# Out:
# US Region                                                       West North Central
# What is typically the main dish at your Thanksgiving dinner?                Turkey
# How is the main dish typically cooked?                                       Baked
# What kind of stuffing/dressing do you typically have?                  Bread-based
# What type of cranberry saucedo you typically have?                          Canned
# Do you typically have gravy?                                                   Yes
# dtype: object

# %%
side_dishes('West North Central')
# Out:
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Mashed potatoes                     65.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Rolls/biscuits                      62.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Green beans/green bean casserole    60.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Corn                                36.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Yams/sweet potato casserole         33.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Fruit salad                         18.0
# ...

# %%
pie('West North Central')
# Out:
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin          57.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple            37.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan            19.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Chocolate        13.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Cherry            9.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - None              4.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Key lime          3.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Sweet Potato      2.0
# ...

# %%
dessert('West North Central')
# Out:
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - None             28.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cookies          16.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Ice cream        14.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Brownies         10.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cheesecake        9.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Apple cobbler     7.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Carrot cake       4.0
# ...

# %% [markdown]
# West North Central
# - main dish: Baked Turkey
# - bread-based stuffing/dressing
# - canned cranberry saucedo
# - with gravy
# - side dishes: Mashed potatoes, Rolls/biscuits and Green beans
# - Pumpkin Pie
# - nothing for dessert

# %% [markdown]
# **East South Central**

# %%
main_dish('East South Central')
# Out:
# US Region                                                       East South Central
# What is typically the main dish at your Thanksgiving dinner?                Turkey
# How is the main dish typically cooked?                                       Baked
# What kind of stuffing/dressing do you typically have?                  Bread-based
# What type of cranberry saucedo you typically have?                          Canned
# Do you typically have gravy?                                                   Yes
# dtype: object

# %%
side_dishes('East South Central')
# Out:
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Rolls/biscuits                      49.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Green beans/green bean casserole    49.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Mashed potatoes                     45.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Yams/sweet potato casserole         44.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Corn                                31.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Macaroni and cheese                 21.0
# ...

# %%
pie('East South Central')
# Out:
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin          38.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan            34.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple            19.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Sweet Potato     18.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Chocolate         9.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Buttermilk        6.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Peach             4.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Cherry            4.0
# ...

# %%
dessert('East South Central')
# Out:
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - None             19.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cheesecake       13.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Peach cobbler     9.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Apple cobbler     9.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cookies           8.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Brownies          6.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Ice cream         5.0
# ...

# %% [markdown]
# East South Central
# - main dish: Baked Turkey
# - bread-based stuffing/dressing
# - canned cranberry saucedo
# - with gravy
# - side dishes: Rolls/biscuits, Green beans and Mashed potatoes
# - Pumpkin Pie
# - nothing for dessert

# %% [markdown]
# **New England**

# %%
main_dish('New England')
# Out:
# US Region                                                       New England
# What is typically the main dish at your Thanksgiving dinner?         Turkey
# How is the main dish typically cooked?                              Roasted
# What kind of stuffing/dressing do you typically have?           Bread-based
# What type of cranberry saucedo you typically have?                   Canned
# Do you typically have gravy?                                            Yes
# dtype: object

# %%
side_dishes('New England')
# Out:
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Mashed potatoes                     52.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Rolls/biscuits                      41.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Yams/sweet potato casserole         34.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Green beans/green bean casserole    33.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Squash                              31.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Carrots                             25.0
# ...

# %%
pie('New England')
# Out:
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin          46.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple            41.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan            17.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Chocolate        12.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Coconut cream     4.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Sweet Potato      3.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - None              2.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Peach             2.0
# ...

# %%
dessert('New England')
# Out:
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Ice cream        21.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cookies          16.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - None             13.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Brownies         11.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cheesecake       10.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Carrot cake       6.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Blondies          6.0
# ...

# %% [markdown]
# New England
# - main dish: Roasted Turkey
# - bread-based stuffing/dressing
# - canned cranberry saucedo
# - with gravy
# - side dishes: Mashed potatoes, Rolls/biscuits and Yams/Sweet potato
# - Pumpkin Pie
# - Ice cream for dessert

# %% [markdown]
# **Mountain**

# %%
main_dish('Mountain')
# Out:
# US Region                                                          Mountain
# What is typically the main dish at your Thanksgiving dinner?         Turkey
# How is the main dish typically cooked?                                Baked
# What kind of stuffing/dressing do you typically have?           Bread-based
# What type of cranberry saucedo you typically have?                   Canned
# Do you typically have gravy?                                            Yes
# dtype: object

# %%
side_dishes('Mountain')
# Out:
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Mashed potatoes                     38.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Rolls/biscuits                      33.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Green beans/green bean casserole    31.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Yams/sweet potato casserole         26.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Corn                                17.0
# Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Vegetable salad                     12.0
# ...

# %%
pie('Mountain')
# Out:
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin          34.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan            20.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple            19.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Cherry            7.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Sweet Potato      4.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Peach             2.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Chocolate         2.0
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - None              1.0
# ...

# %%
dessert('Mountain')
# Out:
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - None             19.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Ice cream        11.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cookies           7.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cheesecake        6.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Carrot cake       4.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Brownies          4.0
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Fudge             2.0
# ...

# %% [markdown]
# Mountain
# - main dish: Baked Turkey
# - bread-based stuffing/dressing
# - canned cranberry saucedo
# - with gravy
# - side dishes: Mashed potatoes, Rolls/biscuits and Green beans
# - Pumpkin Pie
# - Nothing for dessert
